# %%
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
import pandas as pd
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('/content/loan_approval_dataset.csv')
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# 50%      10.000000    600.000000               5.600000e+06
# 75%      16.000000    748.000000               1.130000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.269000e+03          4.269000e+03       4.269000e+03
# mean               4.973155e+06          1.512631e+07       4.976692e+06
# std                4.388966e+06          9.103754e+06       3.250185e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.300000e+06          7.500000e+06       2.300000e+06
# 50%                3.700000e+06          1.460000e+07       4.600000e+06
# 75%                7.600000e+06          2.170000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %%
df.tail()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.rename(columns={' no_of_dependents': 'no_of_dependents'}, inplace=True)

# %%
for i in df.columns[2:]:
  sp=i.strip()
  df.rename(columns={i:sp}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['loan_status'].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df['education']=df['education'].str.strip()
df['loan_status']=df['loan_status'].str.strip()

# %%
df.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      Graduate            No       9600000
# 1        2                 0  Not Graduate           Yes       4100000
# 2        3                 3      Graduate            No       9100000
# 3        4                 3      Graduate            No       8200000
# 4        5                 5  Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
px.box(df,y='residential_assets_value')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="57ac32bc-8f37-4c69-99d0-4526183d1c7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57ac32bc-8f37-4c69-99d0-4526183d1c7b")) {                    Plotly.newPlot(                        "57ac32bc-8f37-4c69-99d0-4526183d1c7b",                        [{"alignmentgroup":"True","hovertemplate":"residential_assets_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":
,8200000,3500000,2300000,1200000,2600000,5200000,7400000,1300000,11400000,2800000,6500000,2800000,4200000,600000,1700000,9500000,1400000,3000000,2200000,9200000,10500000,4000000,11200000,1700000,700000,5200000,3600000,9600000,500000,3400000,9400000,4300000,14300000,2200000,600000,10000000,5600000,3200000,13400000,5800000,6600000,1900000,5400000,2300000,12500000,2800000,6800000,3800000,1500000,8700000,3500000,2100000,1700000,4900000,3800000,3500000,500000,5500000,6400000,3600000,9100000,1200000,4400000,7700000,1900000,6000000,4900000,10200000,600000,4000000,4900000,2400000,12700000,5500000,5500000,7800000,2400000,7500000,6500000,4800000,11900000,1400000,3100000,3300000,4900000,11400000,1500000,500000,10300000,9900000,5400000,400000,3400000,4200000,8800000,7000000,4700000,11300000,3400000,4800000,7600000,5700000,5400000,10400000,11800000,5300000,1400000,3600000,1700000,800000,2800000,4600000,1200000,6300000,3400000,8500000,800000,4600000,4100000,6000000,4400000,7000000,4100000,3300000,5200000,3100000,12400000,100000,6800000,2900000,1000000,6400000,5900000,2700000,2000000,3300000,4900000,4100000,5800000,2100000,6600000,11500000,4500000,3300000,3100000,6800000,11100000,5700000,3400000,5300000,4300000,2800000,8000000,3900000,5000000,12700000,4400000,3900000,4600000,7400000,1500000,0,7000000,6100000,4200000,1900000,4700000,4900000,8400000,3900000,4900000,2400000,8500000,9900000,11500000,4400000,3100000,5900000,3900000,7300000,1400000,7000000,9100000,10800000,2200000,2700000,9000000,7200000,3000000,6200000,5200000,3500000,6800000,6200000,10900000,7300000,6700000,5000000,5000000,11700000,1100000,500000,1300000,500000,700000,12800000,4100000,1900000,8000000,7300000,5200000,700000,7500000,3600000,4900000,2100000,100000,2600000,12900000,2200000,5100000,8200000,7300000,1100000,1400000,700000,1400000,700000,200000,300000,42000 ...

# %%
df.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      Graduate            No       9600000
# 1        2                 0  Not Graduate           Yes       4100000
# 2        3                 3      Graduate            No       9100000
# 3        4                 3      Graduate            No       8200000
# 4        5                 5  Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17050000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
df.sample(5)
# Out:
#       loan_id  no_of_dependents     education self_employed  income_annum  \
# 1393     1394                 0  Not Graduate            No       8700000
# 263       264                 5  Not Graduate            No       9500000
# 1953     1954                 1  Not Graduate            No       4600000
# 509       510                 1      Graduate           Yes       9900000
# 2979     2980                 1  Not Graduate           Yes       3400000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 1393     33600000         14          751                   7100000
# 263      22200000         20          352                  24500000
# 1953     15200000          4          593                  13800000
# 509      39500000         12          808                  11800000
# 2979      7200000          8          741                   4300000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 1393                 13700000             22800000           7000000
# 263                         0             30800000           7000000
# 1953                  3800000             11700000           3900000
# 509                   3700000             30200000          13500000
# 2979                  6600000             11500000           3900000
#
#      loan_status
# 1393    Approved
# 263     Rejected
# 1953    Approved
# 509     Approved
# 2979    Approved

# %%
sns.barplot(x=df['education'],y=df['loan_status'])
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x=df['education'],y=df['loan_status'])
# Out:
# <Axes: xlabel='education', ylabel='loan_status'>

# %%
sns.barplot(x=df['cibil_score'],y=df['loan_status'])
plt.xticks(rotation=46)
plt.show()

# %%
sns.scatterplot(x=df['cibil_score'],y=df['loan_status'])
# Out:
# <Axes: xlabel='cibil_score', ylabel='loan_status'>

# %%
sns.barplot(x=df['income_annum'],y=df['loan_status'])
plt.xticks(rotation=46)
plt.show()

# %%
df.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      Graduate            No       9600000
# 1        2                 0  Not Graduate           Yes       4100000
# 2        3                 3      Graduate            No       9100000
# 3        4                 3      Graduate            No       8200000
# 4        5                 5  Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17050000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
df.sample(5)
# Out:
#       loan_id  no_of_dependents     education self_employed  income_annum  \
# 527       528                 1  Not Graduate           Yes       2100000
# 3107     3108                 3      Graduate           Yes       9000000
# 865       866                 5  Not Graduate           Yes       6400000
# 1753     1754                 3  Not Graduate            No       5500000
# 67         68                 0  Not Graduate           Yes       2700000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 527       4900000         10          744                    200000
# 3107     19800000         20          348                   8600000
# 865      20300000         16          348                  10000000
# 1753     16200000         18          778                   4700000
# 67       10100000         20          693                    200000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# 527                   2000000              5400000           1000000
# 3107                  9200000             25300000           6000000
# 865                  10900000             20400000           6900000
# 1753                 10700000             15300000           6100000
# 67                    1700000              5900000           1400000
#
#      loan_status
# 527     Approved
# 3107    Rejected
# 865     Rejected
# 1753    Approved
# 67      Rejected

# %%
plt.figure(figsize=(13,10))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
print(df['education'].value_counts())
sns.countplot(x=df['education'],color="red")
plt.xticks(rotation=45)
plt.show()
# Out:
# education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64

# %%
print(df['self_employed'].value_counts())
sns.countplot(x=df['self_employed'],color="red")
plt.xticks(rotation=45)
plt.show()
# Out:
# self_employed
#  Yes    2150
#  No     2119
# Name: count, dtype: int64

# %%
print(df['cibil_score'].value_counts())
sns.countplot(x=df['cibil_score'],color="red")
plt.xticks(rotation=45)
plt.show()
# Out:
# cibil_score
# 348    16
# 543    15
# 538    15
# 778    14
# 509    14
#        ..
# 334     2
# 773     2
# 893     2
# 484     2
# 864     1
# Name: count, Length: 601, dtype: int64

# %%
df.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      Graduate            No       9600000
# 1        2                 0  Not Graduate           Yes       4100000
# 2        3                 3      Graduate            No       9100000
# 3        4                 3      Graduate            No       8200000
# 4        5                 5  Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17050000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
sns.distplot(df['bank_asset_value'])
# Out:
# <Axes: xlabel='bank_asset_value', ylabel='Density'>

# %%
a=np.log(df['bank_asset_value'][1])
a
# Out:
# 15.009433026436708

# %%
np.exp(a)
# Out:
# 3299999.999999999

# %%
df.drop(['loan_id'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17050000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value loan_status
# 0             22700000           8000000    Approved
# 1              8800000           3300000    Rejected
# 2             33300000          12800000    Rejected
# 3             23300000           7900000    Rejected
# 4             29400000           5000000    Rejected

# %%
df['Total_assets_value']=df['residential_assets_value']+df['commercial_assets_value']+df['luxury_assets_value']+df['bank_asset_value']

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17050000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value loan_status  Total_assets_value
# 0             22700000           8000000    Approved            50150000
# 1              8800000           3300000    Rejected            17000000
# 2             33300000          12800000    Rejected            57700000
# 3             23300000           7900000    Rejected            52700000
# 4             29400000           5000000    Rejected            55000000

# %%
df.drop(['residential_assets_value','commercial_assets_value','luxury_assets_value','bank_asset_value'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score loan_status  Total_assets_value
# 0         12          778    Approved            50150000
# 1          8          417    Rejected            17000000
# 2         20          506    Rejected            57700000
# 3          8          467    Rejected            52700000
# 4         20          382    Rejected            55000000

# %%
df=pd.get_dummies(df,columns=["education","self_employed"],drop_first=True)

# %%
df.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 2       9600000     29900000         12          778
# 1                 0       4100000     12200000          8          417
# 2                 3       9100000     29700000         20          506
# 3                 3       8200000     30700000          8          467
# 4                 5       9800000     24200000         20          382
#
#   loan_status  Total_assets_value  education_Not Graduate  self_employed_ Yes
# 0    Approved            50150000                   False               False
# 1    Rejected            17000000                    True                True
# 2    Rejected            57700000                   False               False
# 3    Rejected            52700000                   False               False
# 4    Rejected            55000000                    True                True

# %%
df["education_Not Graduate"]=df["education_Not Graduate"].astype('int')

# %%
df["self_employed_ Yes"]=df["self_employed_ Yes"].astype('int')

# %%
df.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 2       9600000     29900000         12          778
# 1                 0       4100000     12200000          8          417
# 2                 3       9100000     29700000         20          506
# 3                 3       8200000     30700000          8          467
# 4                 5       9800000     24200000         20          382
#
#   loan_status  Total_assets_value  education_Not Graduate  self_employed_ Yes
# 0    Approved            50150000                       0                   0
# 1    Rejected            17000000                       1                   1
# 2    Rejected            57700000                       0                   0
# 3    Rejected            52700000                       0                   0
# 4    Rejected            55000000                       1                   1

# %%
df_new=df.copy()

# %%
df_new.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 2       9600000     29900000         12          778
# 1                 0       4100000     12200000          8          417
# 2                 3       9100000     29700000         20          506
# 3                 3       8200000     30700000          8          467
# 4                 5       9800000     24200000         20          382
#
#   loan_status  Total_assets_value  education_Not Graduate  self_employed_ Yes
# 0    Approved            50150000                       0                   0
# 1    Rejected            17000000                       1                   1
# 2    Rejected            57700000                       0                   0
# 3    Rejected            52700000                       0                   0
# 4    Rejected            55000000                       1                   1

# %%
df.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 2       9600000     29900000         12          778
# 1                 0       4100000     12200000          8          417
# 2                 3       9100000     29700000         20          506
# 3                 3       8200000     30700000          8          467
# 4                 5       9800000     24200000         20          382
#
#   loan_status  Total_assets_value  education_Not Graduate  self_employed_ Yes
# 0    Approved            50150000                       0                   0
# 1    Rejected            17000000                       1                   1
# 2    Rejected            57700000                       0                   0
# 3    Rejected            52700000                       0                   0
# 4    Rejected            55000000                       1                   1

# %%
df_new['income_annum_log']=np.log(df_new['income_annum']+1)
df_new['loan_amount_log']=np.log(df_new['loan_amount']+1)

# %%
df_new.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 2       9600000     29900000         12          778
# 1                 0       4100000     12200000          8          417
# 2                 3       9100000     29700000         20          506
# 3                 3       8200000     30700000          8          467
# 4                 5       9800000     24200000         20          382
#
#   loan_status  Total_assets_value  education_Not Graduate  self_employed_ Yes  \
# 0    Approved            50150000                       0                   0
# 1    Rejected            17000000                       1                   1
# 2    Rejected            57700000                       0                   0
# 3    Rejected            52700000                       0                   0
# 4    Rejected            55000000                       1                   1
#
#    income_annum_log  loan_amount_log
# 0         16.077274        17.213369
# 1         15.226498        16.316947
# 2         16.023785        17.206658
# 3         15.919645        17.239773
# 4         16.097893        17.001863

# %%
df_new.drop(['income_annum','loan_amount'],axis=1,inplace=True)

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score loan_status  Total_assets_value  \
# 0                 2         12          778    Approved            50150000
# 1                 0          8          417    Rejected            17000000
# 2                 3         20          506    Rejected            57700000
# 3                 3          8          467    Rejected            52700000
# 4                 5         20          382    Rejected            55000000
#
#    education_Not Graduate  self_employed_ Yes  income_annum_log  \
# 0                       0                   0         16.077274
# 1                       1                   1         15.226498
# 2                       0                   0         16.023785
# 3                       0                   0         15.919645
# 4                       1                   1         16.097893
#
#    loan_amount_log
# 0        17.213369
# 1        16.316947
# 2        17.206658
# 3        17.239773
# 4        17.001863

# %%
df_new['Total_assets_value_log']=np.log(df_new['Total_assets_value']+1)

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score loan_status  Total_assets_value  \
# 0                 2         12          778    Approved            50150000
# 1                 0          8          417    Rejected            17000000
# 2                 3         20          506    Rejected            57700000
# 3                 3          8          467    Rejected            52700000
# 4                 5         20          382    Rejected            55000000
#
#    education_Not Graduate  self_employed_ Yes  income_annum_log  \
# 0                       0                   0         16.077274
# 1                       1                   1         15.226498
# 2                       0                   0         16.023785
# 3                       0                   0         15.919645
# 4                       1                   1         16.097893
#
#    loan_amount_log  Total_assets_value_log
# 0        17.213369               17.730529
# 1        16.316947               16.648724
# 2        17.206658               17.870768
# 3        17.239773               17.780126
# 4        17.001863               17.822844

# %%
df_new.drop(['Total_assets_value'],axis=1,inplace=True)

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score loan_status  \
# 0                 2         12          778    Approved
# 1                 0          8          417    Rejected
# 2                 3         20          506    Rejected
# 3                 3          8          467    Rejected
# 4                 5         20          382    Rejected
#
#    education_Not Graduate  self_employed_ Yes  income_annum_log  \
# 0                       0                   0         16.077274
# 1                       1                   1         15.226498
# 2                       0                   0         16.023785
# 3                       0                   0         15.919645
# 4                       1                   1         16.097893
#
#    loan_amount_log  Total_assets_value_log
# 0        17.213369               17.730529
# 1        16.316947               16.648724
# 2        17.206658               17.870768
# 3        17.239773               17.780126
# 4        17.001863               17.822844

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   no_of_dependents        4269 non-null   int64
#  1   loan_term               4269 non-null   int64
#  2   cibil_score             4269 non-null   int64
#  3   loan_status             4269 non-null   object
#  4   education_Not Graduate  4269 non-null   int64
#  5   self_employed_ Yes      4269 non-null   int64
#  6   income_annum_log        4269 non-null   float64
#  7   loan_amount_log         4269 non-null   float64
#  8   Total_assets_value_log  4269 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 300.3+ KB

# %%
df_new=pd.get_dummies(df_new,columns=["loan_status"],drop_first=True)

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score  education_Not Graduate  \
# 0                 2         12          778                       0
# 1                 0          8          417                       1
# 2                 3         20          506                       0
# 3                 3          8          467                       0
# 4                 5         20          382                       1
#
#    self_employed_ Yes  income_annum_log  loan_amount_log  \
# 0                   0         16.077274        17.213369
# 1                   1         15.226498        16.316947
# 2                   0         16.023785        17.206658
# 3                   0         15.919645        17.239773
# 4                   1         16.097893        17.001863
#
#    Total_assets_value_log  loan_status_Rejected
# 0               17.730529                 False
# 1               16.648724                  True
# 2               17.870768                  True
# 3               17.780126                  True
# 4               17.822844                  True

# %%
df_new["loan_status_Rejected"]=df_new["loan_status_Rejected"].astype('int')

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score  education_Not Graduate  \
# 0                 2         12          778                       0
# 1                 0          8          417                       1
# 2                 3         20          506                       0
# 3                 3          8          467                       0
# 4                 5         20          382                       1
#
#    self_employed_ Yes  income_annum_log  loan_amount_log  \
# 0                   0         16.077274        17.213369
# 1                   1         15.226498        16.316947
# 2                   0         16.023785        17.206658
# 3                   0         15.919645        17.239773
# 4                   1         16.097893        17.001863
#
#    Total_assets_value_log  loan_status_Rejected
# 0               17.730529                     0
# 1               16.648724                     1
# 2               17.870768                     1
# 3               17.780126                     1
# 4               17.822844                     1

# %%
X=df_new.drop(columns=['loan_status_Rejected'])
y=df_new['loan_status_Rejected']

# %%
X.head()
# Out:
#    no_of_dependents  loan_term  cibil_score  education_Not Graduate  \
# 0                 2         12          778                       0
# 1                 0          8          417                       1
# 2                 3         20          506                       0
# 3                 3          8          467                       0
# 4                 5         20          382                       1
#
#    self_employed_ Yes  income_annum_log  loan_amount_log  \
# 0                   0         16.077274        17.213369
# 1                   1         15.226498        16.316947
# 2                   0         16.023785        17.206658
# 3                   0         15.919645        17.239773
# 4                   1         16.097893        17.001863
#
#    Total_assets_value_log
# 0               17.730529
# 1               16.648724
# 2               17.870768
# 3               17.780126
# 4               17.822844

# %%
for i in df.columns[3:5]:
  sp=i.strip()
  df.rename(columns={i:sp}, inplace=True)

# %%
df.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 2       9600000     29900000         12          778
# 1                 0       4100000     12200000          8          417
# 2                 3       9100000     29700000         20          506
# 3                 3       8200000     30700000          8          467
# 4                 5       9800000     24200000         20          382
#
#   loan_status  Total_assets_value  education_Not Graduate  self_employed_ Yes
# 0    Approved            50150000                       0                   0
# 1    Rejected            17000000                       1                   1
# 2    Rejected            57700000                       0                   0
# 3    Rejected            52700000                       0                   0
# 4    Rejected            55000000                       1                   1

# %%
for i in df_new.columns[3:5]:
  sp=i.strip()
  df_new.rename(columns={i:sp}, inplace=True)

# %%
df_new.rename(columns={'education_Not Graduate': 'education_Not_Graduate', 'self_employed_ Yes': 'self_employed_Yes'}, inplace=True)

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score  education_Not_Graduate  \
# 0                 2         12          778                       0
# 1                 0          8          417                       1
# 2                 3         20          506                       0
# 3                 3          8          467                       0
# 4                 5         20          382                       1
#
#    self_employed_Yes  income_annum_log  loan_amount_log  \
# 0                  0         16.077274        17.213369
# 1                  1         15.226498        16.316947
# 2                  0         16.023785        17.206658
# 3                  0         15.919645        17.239773
# 4                  1         16.097893        17.001863
#
#    Total_assets_value_log  loan_status_Rejected
# 0               17.730529                     0
# 1               16.648724                     1
# 2               17.870768                     1
# 3               17.780126                     1
# 4               17.822844                     1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: loan_status_Rejected, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
lr=LinearRegression()
knn=KNeighborsRegressor()
dt=DecisionTreeRegressor(max_depth=17)
rf=RandomForestRegressor(n_estimators=99,random_state=0,max_samples=0.5,max_features=0.75,max_depth=17)
svr=SVR()
xgb=XGBRegressor()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.6149581281620439
# MAE 0.242219204561127
# MSE 0.09139488720867786
# RMSE 0.30231587323307696

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knn.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.8445057274728067
# MAE 0.06323185011709602
# MSE 0.03690866510538642
# RMSE 0.19211628016747154

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=17)

# %%
y_pred=dt.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.9210688971943182
# MAE 0.01990632318501171
# MSE 0.01873536299765808
# RMSE 0.13687718216583097

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=17, max_features=0.75, max_samples=0.5,
#                       n_estimators=99, random_state=0)

# %%
y_pred=rf.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.950087211262737
# MAE 0.028363257871454592
# MSE 0.011847474341264704
# RMSE 0.10884610393240864

# %%
1-(1-r2_score(y_test,y_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9602655460815517

# %%
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_pred=svr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.6956589751574525
# MAE 0.1744519599190222
# MSE 0.07223945153207653
# RMSE 0.26877397852485

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.9606382021558162
# MAE 0.022820291410937044
# MSE 0.009343054190776265
# RMSE 0.096659475431932

# %%
1-(1-r2_score(y_test,y_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9602655460815517

# %%
X_train.head()
# Out:
#       no_of_dependents  loan_term  cibil_score  education_Not Graduate  \
# 2488                 2         18          547                       0
# 3703                 1          8          378                       1
# 3347                 2          6          601                       1
# 3487                 5         12          690                       1
# 3957                 0          4          374                       1
#
#       self_employed_ Yes  income_annum_log  loan_amount_log  \
# 2488                   1         14.808763        15.671809
# 3703                   1         15.943742        17.246267
# 3347                   0         16.087637        17.445171
# 3487                   0         15.732433        16.705882
# 3957                   0         15.274126        16.213406
#
#       Total_assets_value_log
# 2488               16.683410
# 3703               17.851520
# 3347               17.479072
# 3487               17.972830
# 3957               17.161900

# %%
df_new.head()
# Out:
#    no_of_dependents  loan_term  cibil_score  education_Not_Graduate  \
# 0                 2         12          778                       0
# 1                 0          8          417                       1
# 2                 3         20          506                       0
# 3                 3          8          467                       0
# 4                 5         20          382                       1
#
#    self_employed_Yes  income_annum_log  loan_amount_log  \
# 0                  0         16.077274        17.213369
# 1                  1         15.226498        16.316947
# 2                  0         16.023785        17.206658
# 3                  0         15.919645        17.239773
# 4                  1         16.097893        17.001863
#
#    Total_assets_value_log  loan_status_Rejected
# 0               17.730529                     0
# 1               16.648724                     1
# 2               17.870768                     1
# 3               17.780126                     1
# 4               17.822844                     1

# %%
X.head()
# Out:
#    no_of_dependents  loan_term  cibil_score  education_Not Graduate  \
# 0                 2         12          778                       0
# 1                 0          8          417                       1
# 2                 3         20          506                       0
# 3                 3          8          467                       0
# 4                 5         20          382                       1
#
#    self_employed_ Yes  income_annum_log  loan_amount_log  \
# 0                   0         16.077274        17.213369
# 1                   1         15.226498        16.316947
# 2                   0         16.023785        17.206658
# 3                   0         15.919645        17.239773
# 4                   1         16.097893        17.001863
#
#    Total_assets_value_log
# 0               17.730529
# 1               16.648724
# 2               17.870768
# 3               17.780126
# 4               17.822844

# %%
df_new['no_of_dependents'].unique()
# Out:
# array([2, 0, 3, 5, 4, 1])

# %%
X.columns
# Out:
# Index(['no_of_dependents', 'loan_term', 'cibil_score',
#        'education_Not Graduate', 'self_employed_ Yes', 'income_annum_log',
#        'loan_amount_log', 'Total_assets_value_log'],
#       dtype='object')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   no_of_dependents        4269 non-null   int64
#  1   loan_term               4269 non-null   int64
#  2   cibil_score             4269 non-null   int64
#  3   education_Not Graduate  4269 non-null   int64
#  4   self_employed_ Yes      4269 non-null   int64
#  5   income_annum_log        4269 non-null   float64
#  6   loan_amount_log         4269 non-null   float64
#  7   Total_assets_value_log  4269 non-null   float64
# dtypes: float64(3), int64(5)
# memory usage: 266.9 KB

# %%
df_new.columns
# Out:
# Index(['no_of_dependents', 'loan_term', 'cibil_score',
#        'education_Not_Graduate', 'self_employed_Yes', 'income_annum_log',
#        'loan_amount_log', 'Total_assets_value_log', 'loan_status_Rejected'],
#       dtype='object')

# %%
def predict(no_of_dependents, loan_term, cibil_score, education_Not_Graduate, self_employed_Yes, income_annum_log, loan_amount_log, Total_assets_value_log):

  inp_df= xgb.predict([[no_of_dependents	,loan_term	,cibil_score	,education_Not_Graduate	,self_employed_Yes	,income_annum_log	,loan_amount_log,Total_assets_value_log]])

  a=inp_df
  b=np.exp(a)
  final_status=b.astype('int')
  if final_status==1:
    print("Loan Approved")
  else:
    print("Loan Rejected")

# %%
predict(2,12,580,1,1,16.077274,17.213369,17.730529)
# Out:
# Loan Approved

# %%
y_test.value_counts()
# Out:
# loan_status_Rejected
# 0    523
# 1    331
# Name: count, dtype: int64
